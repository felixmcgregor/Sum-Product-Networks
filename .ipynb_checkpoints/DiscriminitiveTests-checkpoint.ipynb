# %%
import numpy as np
import random
from sklearn.utils import shuffle

# %load_ext autoreload
# %autoreload 2

from Node import Node
from SumNode import SumNode
from ProductNode import ProductNode
from Node import LeafNode
from SPN import SPN

# %% [markdown]
# # Discriminitive
# ### XOR example

# %%
x1 = np.array([0.0,0.0])
x2 = np.array([0.0,1.0])
x3 = np.array([1.0,0.0])
x4 = np.array([1.0,1.0])

x5 = np.array([0.0,0.0])
x6 = np.array([0.0,1.0])
x7 = np.array([1.0,0.0])
x8 = np.array([1.0,1.0])

y = np.array([0,0,0,0,1,1,1,1])

# %%
spn = SPN()
# root node id = 0
root_node = SumNode(0, 0)
spn.add_node(root_node)

# Product nodes 1 and 2
prod_node1 = ProductNode(1, 0)
prod_node2 = ProductNode(2, 0)
spn.add_node(prod_node1, random.randint(1,9))
spn.add_node(prod_node2, random.randint(1,9))

# Sum nodes 3 - 6
sum_node3 = SumNode(3,1)
sum_node4 = SumNode(4,2)
sum_node5 = SumNode(5,1)
sum_node6 = SumNode(6,2)
spn.add_node(sum_node3)
spn.add_node(sum_node4)
spn.add_node(sum_node5)
spn.add_node(sum_node6)

# Add leaf nodes
X1 = LeafNode(7,np.array([1]), 0, False)
X_1 = LeafNode(8,np.array([2]), 0, True)
X2 = LeafNode(9,np.array([3,4]), 1, False)
X_2 = LeafNode(10,np.array([3,4]), 1, True)
X3 = LeafNode(11,np.array([5,6]), 2, False)
X_3 = LeafNode(12,np.array([5,6]), 2, True)
spn.add_node(X1, random.randint(1,9))
spn.add_node(X_1, random.randint(1,9))
spn.add_node(X2, random.randint(1,9))
spn.add_node(X_2, random.randint(1,9))
spn.add_node(X3, random.randint(1,9))
spn.add_node(X_3, random.randint(1,9))
spn.normalise_weights()
spn.print_weights()
# Out:
# Node ID 0
# To node 1 :    0.2500
# To node 2 :    0.7500
#
# Node ID 3
# To node 9 :    0.5625
# To node 10 :    0.4375
#
# Node ID 4
# To node 9 :    0.5625
# To node 10 :    0.4375
#
# Node ID 5
# To node 11 :    0.4286
# To node 12 :    0.5714
#
# Node ID 6
# To node 11 :    0.4286
# To node 12 :    0.5714

# %% [markdown]
# ### Forward pass untrained

# %%
print(spn.query(x1))
print(spn.query(x2))
print(spn.query(x3))
print(spn.query(x4))
print(spn.query(x5))
print(spn.query(x6))
print(spn.query(x7))
print(spn.query(x8))
print()
spn.print_weights()
# Out:
# [ 0.328125    0.42857143  0.57142857]
# [ 0.421875    0.42857143  0.57142857]
# [ 0.109375    0.42857143  0.57142857]
# [ 0.140625    0.42857143  0.57142857]
# [ 0.328125    0.42857143  0.57142857]
# [ 0.421875    0.42857143  0.57142857]
# [ 0.109375    0.42857143  0.57142857]
# [ 0.140625    0.42857143  0.57142857]
#
#
# Node ID 0
# To node 1 :    0.2500
# To node 2 :    0.7500
#
# Node ID 3
# To node 9 :    0.5625
# To node 10 :    0.4375
#
# Node ID 4
# To node 9 :    0.5625
# To node 10 :    0.4375
#
# Node ID 5
# To node 11 :    0.4286
# To node 12 :    0.5714
#
# Node ID 6
# To node 11 :    0.4286
# To node 12 :    0.5714

# %%
data = np.array([x1,x2,x3,x4,x5,x6,x7,x8])

print("Training...\n")
for i in range(10):
    spn.discriminitive_hard_gd(data, y)


print("Probability x1",spn.query(x1))
print("Probability x2",spn.query(x2))
print("Probability x3",spn.query(x3))
print("Probability x4",spn.query(x4))
print("Probability x5",spn.query(x5))
print("Probability x6",spn.query(x6))
print("Probability x7",spn.query(x7))
print("Probability x8",spn.query(x8))


spn.print_weights()
# Out:
# Training...
#
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# id 1 difference 0
# id 2 difference 0
# id 9 difference 4
# id 10 difference 4
# id 9 difference 4
# id 10 difference 4
# id 11 difference 4
# id 12 difference 4
# id 11 difference 4
# id 12 difference 4
# Probability x1 [ 0.37486871  0.49979995  0.50020005]
# Probability x2 [ 0.37513129  0.49979995  0.50020005]
# Probability x3 [ 0.12495624  0.49979995  0.50020005]
# Probability x4 [ 0.12504376  0.49979995  0.50020005]
# Probability x5 [ 0.37486871  0.49979995  0.50020005]
# Probability x6 [ 0.37513129  0.49979995  0.50020005]
# Probability x7 [ 0.12495624  0.49979995  0.50020005]
# Probability x8 [ 0.12504376  0.49979995  0.50020005]
#
# Node ID 0
# To node 1 :    0.2500
# To node 2 :    0.7500
#
# Node ID 3
# To node 9 :    0.5002
# To node 10 :    0.4998
#
# Node ID 4
# To node 9 :    0.5002
# To node 10 :    0.4998
#
# Node ID 5
# To node 11 :    0.4998
# To node 12 :    0.5002
#
# Node ID 6
# To node 11 :    0.4998
# To node 12 :    0.5002

# %% [markdown]
# # Example 3

# %%
# generate new dataset
x1 = np.array([0.0,0.0])
x2 = np.array([0.0,1.0])
x3 = np.array([1.0,0.0])
x4 = np.array([1.0,1.0])


data = []
for i in range(603):
    data.append(x1)
for i in range(207):
    data.append(x2)
for i in range(147):
    data.append(x3)
for i in range(43):
    data.append(x4)
    
data = np.array(data)
data = shuffle(data)
print(data.shape)
# Out:
# (10, 2)

# %%
spn = SPN()
# root node id = 0
root_node = SumNode(0, 0)
spn.add_node(root_node)

# Product nodes 1 and 2
prod_node1 = ProductNode(1, 0)
prod_node2 = ProductNode(2, 0)
prod_node3 = ProductNode(3, 0)
spn.add_node(prod_node1, random.randint(1,9))
spn.add_node(prod_node2, random.randint(1,9))
spn.add_node(prod_node3, random.randint(1,9))

# Sum nodes 4 - 7

sum_node4 = SumNode(4,np.array([1,2]))
sum_node5 = SumNode(5,3)
sum_node6 = SumNode(6,1)
sum_node7 = SumNode(7,np.array([2,3]))

spn.add_node(sum_node4)
spn.add_node(sum_node5)
spn.add_node(sum_node6)
spn.add_node(sum_node7)

# Add leaf nodes
X1 = LeafNode(8,np.array([4,5]), 0, False)
X_1 = LeafNode(9,np.array([4,5]), 0, True)
X2 = LeafNode(10,np.array([6,7]), 1, False)
X_2 = LeafNode(11,np.array([6,7]), 1, True)
spn.add_node(X1,  np.array([random.randint(1,9),random.randint(1,9)]) )
spn.add_node(X_1, np.array([random.randint(1,9),random.randint(1,9)]))
spn.add_node(X2, np.array([random.randint(1,9), random.randint(1,9)]) )
spn.add_node(X_2, np.array([random.randint(1,9), random.randint(1,9)]))

spn.normalise_weights()
spn.print_weights()
# Out:
# Node ID 0
# To node 1 :    0.1000
# To node 2 :    0.9000
#
# Node ID 3
# To node 7 :    0.8571
# To node 8 :    0.1429
#
# Node ID 4
# To node 7 :    0.8571
# To node 8 :    0.1429

# %%
print("Training...\n")
for i in range(10):
    spn.discriminitive_hard_gd(data, y)


print("Probability x1",spn.query(x1))
print("Probability x2",spn.query(x2))
print("Probability x3",spn.query(x3))
print("Probability x4",spn.query(x4))


spn.print_weights()
